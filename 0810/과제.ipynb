# %%
#1
fruits = ['apple', 'banana', 'cherry']

#2
fruits[1] = 'blueberry'
print("2번 문제 출력:",fruits)

#3
colors = 'red', 'green', 'blue'

#4
print("4번 문제 출력:", colors[-1])
# Out:
# 2번 문제 출력: ['apple', 'blueberry', 'cherry']
# 4번 문제 출력: blue

# %%
#1
group1 = [1, 2]
group2 = [3, 4]

#2
group1+group2

#3
user_roles = ['admin', 'editor', 'member']

#4
print("'admin' in user_roles:",'admin' in user_roles)

# %%
#1
numbers = [0, 1, 2, 3, 4, 5]

#2
print("2번 문제 numbers[1:4]:",numbers[1:4])

#3
list = [10, 20, 30, 40]

#4
first, *others = list
print(f"4번 문제 first: {first}, others : {others}")

# %%
#1
user_info={'name':"Sparta", 'age':20}

#2
user_info['age'] = 21
print("2번 문제 age: ",user_info['age'])
#3
user_info['role']='admin'
print("3번 문제", user_info)
#4
a = user_info.get('phone',)
print("4번 문제", a, type(a))

#5
a = user_info.get('phone','010-0000-0000')
print("5번 문제", a, type(a))
# Out:
# 2번 문제 age:  21
# 3번 문제 {'name': 'Sparta', 'age': 21, 'role': 'admin'}
# 4번 문제 None <class 'NoneType'>
# 5번 문제 010-0000-0000 <class 'str'>

# %%
#1
raw_emails = ["a@sparta.com", "b@sparta.com", "a@sparta.com"]

#2
raw_emails=set(raw_emails)

#3
refined_emails=list(raw_emails)

#4
print("4번 문제:", refined_emails)
# Out:
# 4번 문제: ['a@sparta.com', 'b@sparta.com']

# %%
#1
menu = {'coffee':4000, 'tea':4500}

#2
print(f"2번 문제 고유 키 목록: {menu.keys()}, 값 데이터: {menu.values()}")

#3
set_a = {1, 2, 3}
set_b = {3, 4, 5}
ㅣ
#4
print("4번 문제 교집합:",set_a&set_b)

#5
print(f"5번 문제 합집합: {set_a|set_b}, 차집합: {set_a-set_b}")
# Out:
# 2번 문제 고유 키 목록: dict_keys(['coffee', 'tea']), 값 데이터: dict_values([4000, 4500])
# 4번 문제 교집합: {3}
# 5번 문제 합집합: {1, 2, 3, 4, 5}, 차집합: {1, 2}
