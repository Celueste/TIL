# %% [markdown]
# #### 3장 2강 : 매핑 및 집합 자료구조

# %% [markdown]
# 1. 딕셔너리(Dictionary) 자료구조

# %% [markdown]
# - key - Value 쌍 구조
# - key: Value를 찾기 위한 키워드, 중복 X, 리스트는 사용 불가, 튜플은 가능
# - Value: key로 찾는 값, 중복O
# - {"키": 값, "키": 값, ...}
#
# - 추가(CREATE): 없는 키 이름으로 값을 대입하면 추가
# - 조회(READ): ['키 이름'] - 키가 없으면 KeyError가 발생
#     - get("키 이름") - 키가 없으면 None 반환
#     - get("키 이름", "기본 값") - 키 이름으로 조회가 되지 않으면 설정된 기본값으로 대체
#     - keys(): 모든 키를 담은 view, 읽기 전용
#     - values(): 모든 값을 담은 view, 읽기 전용
#     - items(): (키, 값) 목록을 담은 view
# - 수정(UPDATE): 이미 있는 키값에 대입하면 수정
#     - update({key, value, key, value, ...})
# - 삭제(DELETE):
#     - del items["키"]
#     - clear(): 전체 비우기
#
# 다른 키-값 쌍 자료형 -> 딕셔너리로 변환
# dict(...)

# %%
user = {
        "email": "test@test.org",
        "password": 1234,
        "name": "김철수"
    }

# %%
user['mobile'] = '010-1000-1000'
user
# Out:
# {'email': 'test@test.org',
#  'password': 1234,
#  'name': '김철수',
#  'mobile': '010-1000-1000'}

# %%
user['name']
# Out:
# '김철수'

# %%
user.keys()
# Out:
# dict_keys(['email', 'password', 'name', 'mobile'])

# %%
user.values()
# Out:
# dict_values(['test@test.org', 1234, '김철수', '010-1000-1000'])

# %%
user.items()
# Out:
# dict_items([('email', 'test@test.org'), ('password', 1234), ('name', '김철수'), ('mobile', '010-1000-1000')])

# %%
user["moblie"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 user["mobile"]
# ----> 2 get["s"]
#
# NameError: name 'get' is not defined

# %%
mobile = user.get("moblie")

type(mobile)
# Out:
# NoneType

# %%
mobile = user.get("moblie", "없음")

mobile, type(mobile)
# Out:
# ('없음', str)

# %%
del user["mobile"]

# %%
user
# Out:
# {'email': 'test@test.org', 'password': 1234, 'name': '김철수'}

# %%
'email' in user
# Out:
# True

# %% [markdown]
# 2. 딕셔너리의 고급 제어

# %% [markdown]
# 3. 집합(Set) 자료구조

# %% [markdown]
# - 중복을 허용하지 않는다.
# - 순서가 결정되지 않는다.
# = {값1, 값2, 값3, ...}
#
# #### 집합 연산
# - 합집합: a | b -> a와 b의 합집합(a.union(b))
# - 교집합: a & b -> a.intersection(b)
# - 차집합: a - b -> a.difference(b)
# - 대칭차집합: a ^ b -> a.symmetric_difference(b)
#
# #### 집합 자료로 형변환
# - set(리스트 또는 튜플)

# %%
a = {10, 10, 10, 20, 30}
a
# Out:
# {10, 20, 30}

# %%
a[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 a[0]
#
# TypeError: 'set' object is not subscriptable

# %%
a = {10, 20 ,30 ,40}
b = {30, 40 ,50 ,60}

print("합집합:", a|b)
print("교집합:", a&b)
print("차집합:", a-b)
print("대칭차집합:", a^b)
# Out:
# 합집합: {40, 10, 50, 20, 60, 30}
# 교집합: {40, 30}
# 차집합: {10, 20}
# 대칭차집합: {10, 50, 20, 60}

# %% [markdown]
# 4. 자료구조 간의 상호 변환과 데이터 정제

# %%
#1
fruits = ['apple', 'banana', 'cherry']

#2
fruits[1] = 'blueberry'
print("2번 문제 출력:",fruits)

#3
colors = 'red', 'green', 'blue'

#4
print("4번 문제 출력:", colors[-1])
# Out:
# 2번 문제 출력: ['apple', 'blueberry', 'cherry']
# 4번 문제 출력: blue

# %%
#1
group1 = [1, 2]
group2 = [3, 4]

#2
group1+group2

#3
user_roles = ['admin', 'editor', 'member']

#4
print("'admin' in user_roles:",'admin' in user_roles)
# Out:
# 'admin' in user_roles: True

# %%
#1
numbers = [0, 1, 2, 3, 4, 5]

#2
print("2번 문제 numbers[1:4]:",numbers[1:4])

#3
list = [10, 20, 30, 40]

#4
first, *others = list
print(f"4번 문제 first: {first}, others : {others}")
# Out:
# 2번 문제 numbers[1:4]: [1, 2, 3]
# 4번 문제 first: 10, others : [20, 30, 40]
