# %%
#1
current_temp = 32

if current_temp >= 30:
    print("폭염 주의보가 발령되었습니다.")
else:
    print("쾌적한 날씨입니다.")

#2
current_temp = 25

if current_temp >= 30:
    print("폭염 주의보가 발령되었습니다.")
else:
    print("쾌적한 날씨입니다.")
# Out:
# 폭염 주의보가 발령되었습니다.
# 쾌적한 날씨입니다.

# %%
#1
weight = 20
if weight > 23:
    print("대형 수하물 대상입니다.")
elif weight > 15:
    print("일반 위탁 수하물 대상입니다.")
else:
    print("무료 수하물 대상입니다.")

#2
weight = 25
if weight > 23:
    print("대형 수하물 대상입니다.")
elif weight > 15:
    print("일반 위탁 수하물 대상입니다.")
else:
    print("무료 수하물 대상입니다.")

#3
weight = 10
if weight > 23:
    print("대형 수하물 대상입니다.")
elif weight > 15:
    print("일반 위탁 수하물 대상입니다.")
else:
    print("무료 수하물 대상입니다.")
# Out:
# 일반 위탁 수하물 대상입니다.
# 대형 수하물 대상입니다.
# 무료 수하물 대상입니다.

# %%
age = 14
height = 135

if age >= 14 and height >= 135:
    print("탑승 가능합니다. 관리자 확인을 진행하십시오.")
else:
    print("탑승 요건을 만족하지 못했습니다.")
# Out:
# 탑승 가능합니다. 관리자 확인을 진행하십시오.

# %%
#1
배터리잔량 = 0
초기값 = 80

while 초기값 <= 100:
    배터리잔량 = 초기값
    초기값 += 5
    print("현재 배터리: ",배터리잔량)
# Out:
# 현재 배터리:  80
# 현재 배터리:  85
# 현재 배터리:  90
# 현재 배터리:  95
# 현재 배터리:  100

# %%
for i in range(1,5):
    print(f"{i}번째 고객님입니다.")
# Out:
# 1번째 고객님입니다.
# 2번째 고객님입니다.
# 3번째 고객님입니다.
# 4번째 고객님입니다.

# %%
for i in range(1,3):
    for j in range(1,4):
        print(f"{i}층 {j}호")
# Out:
# 1층 1호
# 1층 2호
# 1층 3호
# 2층 1호
# 2층 2호
# 2층 3호
