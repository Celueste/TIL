# %%
list_test = [1,2,1,2]
value = 2

while value in list_test:
    list_test.remove(value)


print(list_test)
# Out:
# [1, 1]

# %%
import time
number = 0

target_tick = time.time()+5
while time.time() < target_tick:
    number += 1

print("5초 동안 {}번 반복했습니다.".format(number))
# Out:
# 5초 동안 79866900번 반복했습니다.

# %%
i = 0

while True:
    print("{}번째 반복문입니다.".format(i))
    i = i + 1

    input_text = input("> 종료하시겠습니까?(y/n): ")
    if input_text in ["y", "Y"]:
        print("반복을 종료합니다.")
        break
# Out:
# 0번째 반복문입니다.
# 1번째 반복문입니다.
# 2번째 반복문입니다.
# 반복을 종료합니다.

# %%
print(list(range(5))) # 0,1,2,3,4
print(list(range(4,6))) # 4,5
print(list(range(7,0,-1))) # 7,6,5,4,3,2,1
print(list(range(3,10,3))) # 3,6,9
# Out:
# [0, 1, 2, 3, 4]
# [4, 5]
# [7, 6, 5, 4, 3, 2, 1]
# [3, 6, 9]

# %%
key_list = ['name','hp','mp','level']
value_list = ['기사', 200, 30, 5]
character = {}

for i in range(len(key_list)):
    character[key_list[i]] = value_list[i]
print(character)
# Out:
# {'name': '기사', 'hp': 200, 'mp': 30, 'level': 5}

# %%
limit = 10000
i = 1
sum_value = 0

while sum_value <= limit:    
    sum_value += i
    i += 1
print(f"{i-1}를 더할 때 {limit}를 넘으며 그때의 값은 {sum_value}입니다. ")
# Out:
# 141를 더할 때 10000를 넘으며 그때의 값은 10011입니다.

# %%
max_value = 0
a=0
b=0

for i in range(1, 51):
    j = 100 - i
    if i * j > max_value:
        a = i
        b = j
        max_value = a * b

print(f"최대가 되는 경우: {i}번째 {a} * {b} = {max_value}")
# Out:
# 최대가 되는 경우: 50번째 50 * 50 = 2500

# %%
list_a = [1,2,3,4,5]
list_reversed = reversed(list_a)

print(list_reversed)
print(list(list_reversed))
print()

for i in reversed(list_a):
    print(i)
# Out:
# ...
# [5, 4, 3, 2, 1]
#
# 5
# 4
# 3
# 2
# 1

# %%
example_list = ['요소a','b','c']
for i in range(len(example_list)):
    print(f"{i}번째 요소는 {example_list[i]}입니다.")
# Out:
# 0번째 요소는 요소a입니다.
# 1번째 요소는 b입니다.
# 2번째 요소는 c입니다.

# %%
example_list = ['요소a','b','c']
i=0
for item in example_list:
    print(f"{i}번째 요소는 {item}입니다.")
    i +=1
# Out:
# 0번째 요소는 요소a입니다.
# 1번째 요소는 b입니다.
# 2번째 요소는 c입니다.

# %%
example_list = ['요소a','b','c']

# for i, value in enumerate(example_list):
#     print(f"{i}번째 요소는 {value}입니다.")

print(list(enumerate(example_list)))
for i in enumerate(example_list):
    print(f"{i[0]}번째 요소는 {i[1]}입니다.")
# Out:
# [(0, '요소a'), (1, 'b'), (2, 'c')]
# 0번째 요소는 요소a입니다.
# 1번째 요소는 b입니다.
# 2번째 요소는 c입니다.

# %%
example_dictionary = {
    "키A":"값A",
    "키B":"값B",
    "키C":"값C"
}

print(example_dictionary.items())

for key, element in example_dictionary.items():
    print(key, element)
# Out:
# dict_items([('키A', '값A'), ('키B', '값B'), ('키C', '값C')])
# 키A 값A
# 키B 값B
# 키C 값C

# %%
array = []

for i in range(0, 20, 2):
    array.append(i**2)  #append 추가 하는 거. array = [] 원래 비어있음

print(array)
# Out:
# [0, 4, 16, 36, 64, 100, 144, 196, 256, 324]

# %%
array = [i**2 for i in range(0, 20, 2)]

print(array)
# Out:
# [0, 4, 16, 36, 64, 100, 144, 196, 256, 324]

# %%
array = ['사과','자두','초콜릿','바나나','체리']
output = [fruit
          for fruit in array
          if fruit != "초콜릿"]

print(output)
# Out:
# ['사과', '자두', '바나나', '체리']

# %%
number = int(input("정수 입력:> "))

# %%
numbers = [1, 2, 3, 4, 5, 6]
r_num = reversed(numbers) 

print(r_num) # reversed()함수를 사용하였을때 주소 처럼 출력됨. 이 리턴값이 바로 이터레이터.
print(next(r_num))
print(next(r_num))
print(next(r_num))
print(next(r_num))
# Out:
# ...
# 6
# 5
# 4
# 3

# %% [markdown]
# reversed() 함수는 매개변수에 리스트를 넣으면 요소의 순서를 뒤집을 수 있다.
# enumerate() 함수는 매개변수에 리스트를 넣으면 인덱스와 값을 쌍으로 사용해 반복문을 돌릴 수 있게 해주는 함수
# items() 함수는 키와 쌍으로 사용해 반복문을 돌릴수 있게 해주는 딕셔너리 함수
# 리스트내포는 반복문과 조건문을 대괄호 안에 넣는 형태를 사용해서 리스트를 생성하는 파이썬의 특수한 구문

# %%
output=[]

for i in range(1,101):
    x = f"{i:b}"
    if x.count("0") == 1:
        # output.append(x)
        print(i, ":", x)
        output.append(i)
print("합계:",sum(output))
# Out:
# 2 : 10
# 5 : 101
# 6 : 110
# 11 : 1011
# 13 : 1101
# 14 : 1110
# 23 : 10111
# 27 : 11011
# 29 : 11101
# 30 : 11110
# 47 : 101111
# 55 : 110111
# 59 : 111011
# 61 : 111101
# 62 : 111110
# 95 : 1011111
# 합계: 539

# %%
output=[
    i
    for i in range(1,101)
    if f"{i:b}".count("0") == 1
        ]
for i in output:
    print(i)
print(sum(output))
# Out:
# 539
