# %% [markdown]
# #### 5장 3강 : 클로저와 데코레이터

# %% [markdown]
# ### 1. 파이썬 함수의 일급 객체 특성과 고차 함수

# %% [markdown]
# ### 2. 클로저(Closure)

# %% [markdown]
# - 고차 함수(Higher Order Function)

# %%
def outer():
    num1 = 10
    def inner():
        num2 = 20
        print(num1 + num2)

    return inner
inner = outer() # num1은 inner에 의해서 사용되므로 힙 영역에 생성되어 있음
inner()
# Out:
# 30

# %%
def add(num1):
    def _add(num2):
        def __add(num3):
            return num1 + num2 + num3
        return __add
    return _add

# %%
result1 = add(10)(20)(30)

result1
# Out:
# 60

# %%
add10 = add(10)
add10(30)(40)
# Out:
# 80

# %%
add10_20=add(10)(20)

add10_20(30)
# Out:
# 60

# %% [markdown]
# ### 3. 데코레이터(Decorator)

# %% [markdown]
# - 디자인 패턴 중 한가지
# -

# %%
def factorial1(num):
    result = 1
    
    for i in range(1, num+1):
        result *= i

    return result
# Out:
# 3628800

# %%
import time

start = time.time()

result = factorial1(10)
print(result)

end = time.time()
print("걸린시간: ", end - start)
# Out:
# 3628800
# 걸린시간:  0.00012445449829101562

# %%
# 같은 함수 내에서 같은 함수를 반복해서 호출하는 방법 - 재귀 함수(Recursive)
def factorial2(num):
    if (num < 1):
        return 1
    return num * factorial2(num -1)

# %%
start = time.time() # 공통 기능

result = factorial2(10) # 핵심기능
print(result)

end = time.time() # 공통 기능
print("걸린시간: ", end - start)
# Out:
# 3628800
# 걸린시간:  0.00011587142944335938

# %%
import time
def time_checker(callback, num):
    start = time.time() # 공통 기능

    result = callback(num) # 핵심 기능 - 팩토리얼 연산 함수(factorial1, factorial2)

    end = time.time() # 공통 기능
    print("걸린시간:", end - start)

    return result

# %%
time_checker(factorial1, 10)
time_checker(factorial2, 10)
# Out:
# 걸린시간: 1.6689300537109375e-06
# 걸린시간: 1.6689300537109375e-06
# 3628800

# %%
import time
def time_check2(callback):
    def wrapper(*args, **kwargs):
        start = time.time() # 공통 기능

        result = callback(*args, **kwargs) # 핵심기능
        
        end = time.time() # 공통 기능
        print("걸린시간:", end - start)

        return result
    return wrapper

# %%
@time_check2
def factorial2(num):
    if (num < 1):
        return 1
    return num * factorial2(num -1)

# %%
factorial2(10)
# Out:
# 걸린시간: 4.76837158203125e-07
# 걸린시간: 0.00014138221740722656
# 걸린시간: 0.00014925003051757812
# 걸린시간: 0.0001556873321533203
# 걸린시간: 0.00016188621520996094
# 걸린시간: 0.00016808509826660156
# 걸린시간: 0.00017380714416503906
# 걸린시간: 0.00017952919006347656
# 걸린시간: 0.0001862049102783203
# 걸린시간: 0.00019168853759765625
# 걸린시간: 0.0001983642578125
# 3628800

# %%
@time_check2
def add(num1, num2):
    return num1 + num2

# %%
add(10, 20)
# Out:
# 걸린시간: 7.152557373046875e-07
# 30

# %%
a = [10, 20]

def minus(num1, num2):
    return num1 - num2

minus(*a)
# Out:
# -10
